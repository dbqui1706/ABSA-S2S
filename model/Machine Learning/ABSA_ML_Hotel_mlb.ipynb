# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/NLU_NCKH/notebook/hotel_data_pre/'
# Out:
# /content/drive/MyDrive/NLU_NCKH/notebook/hotel_data_pre

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import sklearn
sklearn.set_config(enable_metadata_routing=True)

# %% [markdown]
# # Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import torch
from sklearn.metrics import *

# %% [markdown]
# # Load data

# %%
df_train = pd.read_csv("./Train.csv")
df_dev = pd.read_csv("./Dev.csv")
df_test = pd.read_csv("./Test.csv")

print("Train: ", df_train.shape)
print("Dev: ",  df_dev.shape)
print("Test: ", df_test.shape )
# Out:
# Train:  (7180, 35)
# Dev:  (795, 35)
# Test:  (2030, 35)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

aspects = df_train.columns[1:]
def make_outputs(df):
    outputs = []
    for row in range(len(df)):
        row_one_hot = []
        for col in range(1, len(df.columns)):
            sentiment = df.iloc[row, col]
            if   sentiment == 0: one_hot = [1, 0, 0, 0] # None
            elif sentiment == 1: one_hot = [0, 1, 0, 0] # Pos
            elif sentiment == 2: one_hot = [0, 0, 1, 0] # Neg
            elif sentiment == 3: one_hot = [0, 0, 0, 1] # Neu
            row_one_hot.append(one_hot)
        outputs.append(np.array(row_one_hot).reshape(-1))
    return np.array(outputs, dtype='uint8')

x_train = df_train['review']
y_train_136 = make_outputs(df_train)
y_train = df_train[df_train.columns[1:]]

x_test = df_test['review']
y_test_136 = make_outputs(df_test)
y_test = df_test[df_test.columns[1:]]


vectorizer = TfidfVectorizer(ngram_range=(1, 3),
                             min_df=2, max_df=0.9)

# x data using basic clean up class and basic features extrator
x_train = vectorizer.fit_transform(x_train)
x_test   = vectorizer.transform(x_test)

x_train.shape, y_train.shape
# Out:
# ((7180, 19589), (7180, 34))

# %%
import os
import math
from tqdm import tqdm, trange
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, f1_score

label_map= {'None': 0,
            'negative':1,
            'neutral':2,
            'positive':3}

replacements={0: 'None',
              1: 'negative',
              2: 'neutral',
              3: 'positive'}
target_names = list(map(str, replacements.values()))

def aspect_detection_eval(y_test, y_pred):
  """
  y_test: grouth_true test, DataFrame
  y_pred: grouth_true predict, DataFrame
  """
  categories= y_pred.columns
  y_test= y_test.fillna('not_exist').replace(label_map).values.tolist()
  y_pred= y_pred.fillna('not_exist').replace(label_map).values.tolist()

  aspect_test = []
  aspect_pred = []

  for row_test, row_pred in zip(y_test, y_pred):
      for index, (col_test, col_pred) in enumerate(zip(row_test, row_pred)):
          aspect_test.append(bool(col_test) * categories[index])
          aspect_pred.append(bool(col_pred) * categories[index])

  print("## Aspect Detection Evaluate ##")
  print("F1-score micro: ", f1_score(aspect_test, aspect_pred, average='micro'))
  print("F1-score macro: ", f1_score(aspect_test, aspect_pred, average='macro'))
  print(classification_report(aspect_test, aspect_pred, digits=4, zero_division=1))
  return classification_report(aspect_test, aspect_pred, digits=4, zero_division=1, output_dict=True)


def sentiment_classification_eval(y_test, y_pred):
  """
  y_test: grouth_true test, DataFrame
  y_pred: grouth_true predict, DataFrame
  """
  categories= y_pred.columns
  y_test= y_test.fillna('not_exist').replace(label_map).values.tolist()
  y_pred= y_pred.fillna('not_exist').replace(label_map).values.tolist()

  y_test_flat = np.array(y_test).flatten()
  y_pred_flat = np.array(y_pred).flatten()
  target_names = list(map(str, replacements.values()))

  print("## Sentiment Classification Evaluate ##")
  print("F1-score micro: ", f1_score(y_test_flat, y_pred_flat, average='micro'))
  print("F1-score macro: ", f1_score(y_test_flat, y_pred_flat, average='macro'))
  print(classification_report(y_test_flat, y_pred_flat, target_names=target_names, digits=4))

  return classification_report(y_test_flat, y_pred_flat, digits=4, output_dict=True)

def combination_eval(y_test, y_pred):
  """
  y_test: grouth_true test, DataFrame
  y_pred: grouth_true predict, DataFrame
  """
  categories= y_pred.columns
  y_test= y_test.fillna('not_exist').replace(label_map).values.tolist()
  y_pred= y_pred.fillna('not_exist').replace(label_map).values.tolist()

  aspect_polarity_test = []
  aspect_polarity_pred = []

  for row_test, row_pred in zip(y_test, y_pred):
      for index, (col_test, col_pred) in enumerate(zip(row_test, row_pred)):
          aspect_polarity_test.append(f'{categories[index]},{replacements[col_test]}')
          aspect_polarity_pred.append(f'{categories[index]},{replacements[col_pred]}')

  print("## Combination Evaluate (Aspect + Polarity dection) ##")
  print("F1-score micro: ", f1_score(aspect_polarity_test, aspect_polarity_pred, average='micro'))
  print("F1-score macro: ", f1_score(aspect_polarity_test, aspect_polarity_pred, average='macro'))
  print(classification_report(aspect_polarity_test, aspect_polarity_pred, digits=4, zero_division=1))
  return classification_report(aspect_polarity_test, aspect_polarity_pred, digits=4, zero_division=1)

# %%
def analyze_label_distribution(y):
      label_counts = np.sum(y, axis=0)
      total_samples = y.shape[0]

      print("Label distribution:")
      for i, count in enumerate(label_counts):
          percentage = (count / total_samples) * 100
          print(f"Label {i}: {count} ({percentage:.2f}%)")

      print("\nLabels with potential issues:")
      for i, count in enumerate(label_counts):
          if count == 0:
              print(f"Label {i}: No positive samples")
          elif count == total_samples:
              print(f"Label {i}: No negative samples")
      return label_counts

label_counts = analyze_label_distribution(y_train_136)
# Identify problematic labels
zero_labels = np.where(label_counts == 0)[0]
all_one_labels = np.where(label_counts == y_train.shape[0])[0]

print("Labels with all zeros:", zero_labels)
print("Labels with all ones:", all_one_labels)
# Out:
# Label distribution:
# Label 0: 7122 (99.19%)
# Label 1: 42 (0.58%)
# Label 2: 2 (0.03%)
# Label 3: 14 (0.19%)
# Label 4: 7158 (99.69%)
# Label 5: 11 (0.15%)
# Label 6: 0 (0.00%)
# Label 7: 11 (0.15%)
# Label 8: 7121 (99.18%)
# Label 9: 27 (0.38%)
# Label 10: 0 (0.00%)
# Label 11: 32 (0.45%)
# Label 12: 7020 (97.77%)
# Label 13: 23 (0.32%)
# Label 14: 10 (0.14%)
# Label 15: 127 (1.77%)
# Label 16: 7140 (99.44%)
# Label 17: 35 (0.49%)
# Label 18: 2 (0.03%)
# Label 19: 3 (0.04%)
# Label 20: 7159 (99.71%)
# Label 21: 11 (0.15%)
# Label 22: 3 (0.04%)
# Label 23: 7 (0.10%)
# Label 24: 7101 (98.90%)
# Label 25: 60 (0.84%)
# Label 26: 1 (0.01%)
# Label 27: 18 (0.25%)
# Label 28: 7148 (99.55%)
# Label 29: 27 (0.38%)
# Label 30: 1 (0.01%)
# Label 31: 4 (0.06%)
# Label 32: 7149 (99.57%)
# Label 33: 15 (0.21%)
# Label 34: 4 (0.06%)
# Label 35: 12 (0.17%)
# Label 36: 6815 (94.92%)
# Label 37: 88 (1.23%)
# Label 38: 36 (0.50%)
# Label 39: 241 (3.36%)
# Label 40: 6916 (96.32%)
# Label 41: 145 (2.02%)
# Label 42: 12 (0.17%)
# Label 43: 107 (1.49%)
# Label 44: 6994 (97.41%)
# Label 45: 15 (0.21%)
# Label 46: 7 (0.10%)
# Label 47: 164 (2.28%)
# Label 48: 6263 (87.23%)
# Label 49: 93 (1.30%)
# Label 50: 15 (0.21%)
# Label 51: 809 (11.27%)
# Label 52: 6897 (96.06%)
# Label 53: 22 (0.31%)
# Label 54: 5 (0.07%)
# Label 55: 256 (3.57%)
# Label 56: 5970 (83.15%)
# Label 57: 62 (0.86%)
# Label 58: 220 (3.06%)
# Label 59: 928 (12.92%)
# Label 60: 7094 (98.80%)
# Label 61: 49 (0.68%)
# Label 62: 13 (0.18%)
# Label 63: 24 (0.33%)
# Label 64: 6552 (91.25%)
# Label 65: 46 (0.64%)
# Label 66: 27 (0.38%)
# Label 67: 555 (7.73%)
# Label 68: 6896 (96.04%)
# Label 69: 53 (0.74%)
# Label 70: 37 (0.52%)
# Label 71: 194 (2.70%)
# Label 72: 6224 (86.69%)
# Label 73: 95 (1.32%)
# Label 74: 19 (0.26%)
# Label 75: 842 (11.73%)
# Label 76: 6127 (85.33%)
# Label 77: 129 (1.80%)
# Label 78: 6 (0.08%)
# Label 79: 918 (12.79%)
# Label 80: 6794 (94.62%)
# Label 81: 112 (1.56%)
# Label 82: 2 (0.03%)
# Label 83: 272 (3.79%)
# Label 84: 6695 (93.25%)
# Label 85: 151 (2.10%)
# Label 86: 8 (0.11%)
# Label 87: 326 (4.54%)
# Label 88: 6934 (96.57%)
# Label 89: 31 (0.43%)
# Label 90: 43 (0.60%)
# Label 91: 172 (2.40%)
# Label 92: 7142 (99.47%)
# Label 93: 31 (0.43%)
# Label 94: 4 (0.06%)
# Label 95: 3 (0.04%)
# Label 96: 7118 (99.14%)
# Label 97: 9 (0.13%)
# Label 98: 5 (0.07%)
# Label 99: 48 (0.67%)
# Label 100: 6969 (97.06%)
# Label 101: 52 (0.72%)
# Label 102: 13 (0.18%)
# Label 103: 146 (2.03%)
# Label 104: 7129 (99.29%)
# Label 105: 38 (0.53%)
# Label 106: 1 (0.01%)
# Label 107: 12 (0.17%)
# Label 108: 7136 (99.39%)
# Label 109: 32 (0.45%)
# Label 110: 1 (0.01%)
# Label 111: 11 (0.15%)
# Label 112: 7072 (98.50%)
# Label 113: 25 (0.35%)
# Label 114: 0 (0.00%)
# Label 115: 83 (1.16%)
# Label 116: 6480 (90.25%)
# Label 117: 35 (0.49%)
# Label 118: 17 (0.24%)
# Label 119: 648 (9.03%)
# Label 120: 7043 (98.09%)
# Label 121: 125 (1.74%)
# Label 122: 3 (0.04%)
# Label 123: 9 (0.13%)
# Label 124: 7178 (99.97%)
# Label 125: 1 (0.01%)
# Label 126: 1 (0.01%)
# Label 127: 0 (0.00%)
# Label 128: 6960 (96.94%)
# Label 129: 147 (2.05%)
# Label 130: 7 (0.10%)
# Label 131: 66 (0.92%)
# Label 132: 4883 (68.01%)
# Label 133: 266 (3.70%)
# Label 134: 129 (1.80%)
# Label 135: 1902 (26.49%)
#
# Labels with potential issues:
# Label 6: No positive samples
# Label 10: No positive samples
# Label 114: No positive samples
# Label 127: No positive samples
# Labels with all zeros: [  6  10 114 127]
# Labels with all ones: []

# %%
from sklearn.svm import LinearSVC
from sklearn.multioutput import MultiOutputClassifier as MOC
from sklearn.multioutput import ClassifierChain as MOC_CC

# If you find labels with no positive or negative samples, you may want to remove them
base_clf = LinearSVC()
cc_clf = MOC_CC(base_clf)
cc_clf.fit(x_train, y_train)
ypred_svm_cc = cc_clf.predict(x_test)


clf_moc = MOC(LinearSVC())
clf_moc.fit(x_train, y_train)
ypred_svm_moc = clf_moc.predict(x_test)

# %% [markdown]
# # Evaluate

# %%
y_pred = ypred_svm_cc
y_test_rs = y_test

# y_test_flat = np.argmax(y_test_rs, axis=2)
# y_pred = np.argmax(ypred_svm_moc_rs, axis=2)

# Evaluate Classifier Chain
ad = aspect_detection_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
ast = sentiment_classification_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
cp = combination_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
# Out:
# ## Aspect Detection Evaluate ##
# F1-score micro:  0.9780353520718632
# F1-score macro:  0.4402872320437999
#                                 precision    recall  f1-score   support
#
#                                    0.9828    0.9943    0.9885     65760
#         FACILITIES#CLEANLINESS     1.0000    0.3750    0.5455        16
#             FACILITIES#COMFORT     1.0000    0.0000    0.0000         6
#     FACILITIES#DESIGN&FEATURES     1.0000    0.2941    0.4545        17
#             FACILITIES#GENERAL     0.5833    0.1556    0.2456        45
#       FACILITIES#MISCELLANEOUS     1.0000    0.0909    0.1667        11
#              FACILITIES#PRICES     1.0000    0.0000    0.0000         6
#             FACILITIES#QUALITY     1.0000    0.1818    0.3077        22
#      FOOD&DRINKS#MISCELLANEOUS     1.0000    0.0000    0.0000         9
#             FOOD&DRINKS#PRICES     1.0000    0.0000    0.0000         8
#            FOOD&DRINKS#QUALITY     0.8857    0.6078    0.7209       102
#      FOOD&DRINKS#STYLE&OPTIONS     0.9153    0.7297    0.8120        74
#              HOTEL#CLEANLINESS     0.8235    0.2692    0.4058        52
#                  HOTEL#COMFORT     0.8207    0.5922    0.6879       255
#          HOTEL#DESIGN&FEATURES     0.7188    0.2911    0.4144        79
#                  HOTEL#GENERAL     0.7542    0.5387    0.6285       336
#            HOTEL#MISCELLANEOUS     1.0000    0.1250    0.2222        24
#                   HOTEL#PRICES     0.8889    0.8736    0.8812       174
#                  HOTEL#QUALITY     0.8491    0.5696    0.6818        79
#               LOCATION#GENERAL     0.9567    0.9135    0.9346       266
#              ROOMS#CLEANLINESS     0.8815    0.8635    0.8724       293
#                  ROOMS#COMFORT     0.7593    0.3832    0.5093       107
#          ROOMS#DESIGN&FEATURES     0.7765    0.4889    0.6000       135
#                  ROOMS#GENERAL     0.6000    0.1324    0.2169        68
#            ROOMS#MISCELLANEOUS     1.0000    0.0000    0.0000        11
#                   ROOMS#PRICES     1.0000    0.1765    0.3000        17
#                  ROOMS#QUALITY     0.9118    0.5254    0.6667        59
#     ROOM_AMENITIES#CLEANLINESS     1.0000    0.1429    0.2500        14
#         ROOM_AMENITIES#COMFORT     0.5000    0.0833    0.1429        12
# ROOM_AMENITIES#DESIGN&FEATURES     0.5714    0.1333    0.2162        30
#         ROOM_AMENITIES#GENERAL     0.8209    0.8462    0.8333       195
#   ROOM_AMENITIES#MISCELLANEOUS     0.6875    0.2895    0.4074        38
#          ROOM_AMENITIES#PRICES     1.0000    0.0000    0.0000         1
#         ROOM_AMENITIES#QUALITY     0.7500    0.2951    0.4235        61
#                SERVICE#GENERAL     0.8648    0.8824    0.8735       638
#
#                       accuracy                         0.9780     69020
#                      macro avg     0.8658    0.3670    0.4403     69020
#                   weighted avg     0.9760    0.9780    0.9751     69020
#
# ## Sentiment Classification Evaluate ##
# F1-score micro:  0.9754998551144596
# F1-score macro:  0.6019438196953268
#               precision    recall  f1-score   support
#
#         None     0.9828    0.9943    0.9885     65760
#     negative     0.6992    0.3015    0.4213       617
#      neutral     0.5263    0.1657    0.2521       181
#     positive     0.7962    0.7015    0.7458      2462
#
#     accuracy                         0.9755     69020
#    macro avg     0.7512    0.5407    0.6019     69020
# weighted avg     0.9724    0.9755    0.9729     69020
#
# ## Combination Evaluate (Aspect + Polarity dection) ##
# F1-score micro:  0.9754998551144596
# F1-score macro:  0.46285723462642325
#                                          precision    recall  f1-score   support
#
#             FACILITIES#CLEANLINESS,None     0.9951    1.0000    0.9975      2014
#         FACILITIES#CLEANLINESS,negative     0.8000    0.3636    0.5000        11
#         FACILITIES#CLEANLINESS,positive     1.0000    0.2000    0.3333         5
#                 FACILITIES#COMFORT,None     0.9970    1.0000    0.9985      2024
#             FACILITIES#COMFORT,negative     1.0000    0.0000    0.0000         4
#             FACILITIES#COMFORT,positive     1.0000    0.0000    0.0000         2
#         FACILITIES#DESIGN&FEATURES,None     0.9941    1.0000    0.9970      2013
#     FACILITIES#DESIGN&FEATURES,negative     1.0000    0.2500    0.4000        12
#     FACILITIES#DESIGN&FEATURES,positive     0.5000    0.2000    0.2857         5
#                 FACILITIES#GENERAL,None     0.9812    0.9975    0.9893      1985
#             FACILITIES#GENERAL,negative     1.0000    0.0000    0.0000         6
#              FACILITIES#GENERAL,neutral     1.0000    0.0000    0.0000         3
#             FACILITIES#GENERAL,positive     0.5833    0.1944    0.2917        36
#           FACILITIES#MISCELLANEOUS,None     0.9951    1.0000    0.9975      2019
#       FACILITIES#MISCELLANEOUS,negative     1.0000    0.1111    0.2000         9
#       FACILITIES#MISCELLANEOUS,positive     1.0000    0.0000    0.0000         2
#                  FACILITIES#PRICES,None     0.9970    1.0000    0.9985      2024
#              FACILITIES#PRICES,negative     1.0000    0.0000    0.0000         4
#              FACILITIES#PRICES,positive     1.0000    0.0000    0.0000         2
#                 FACILITIES#QUALITY,None     0.9911    1.0000    0.9955      2008
#             FACILITIES#QUALITY,negative     1.0000    0.2857    0.4444        14
#              FACILITIES#QUALITY,neutral     1.0000    0.0000    0.0000         1
#             FACILITIES#QUALITY,positive     1.0000    0.0000    0.0000         7
#          FOOD&DRINKS#MISCELLANEOUS,None     0.9956    1.0000    0.9978      2021
#      FOOD&DRINKS#MISCELLANEOUS,negative     1.0000    0.0000    0.0000         8
#      FOOD&DRINKS#MISCELLANEOUS,positive     1.0000    0.0000    0.0000         1
#                 FOOD&DRINKS#PRICES,None     0.9961    1.0000    0.9980      2022
#             FOOD&DRINKS#PRICES,negative     1.0000    0.0000    0.0000         5
#             FOOD&DRINKS#PRICES,positive     1.0000    0.0000    0.0000         3
#                FOOD&DRINKS#QUALITY,None     0.9796    0.9959    0.9877      1928
#            FOOD&DRINKS#QUALITY,negative     0.9167    0.4074    0.5641        27
#             FOOD&DRINKS#QUALITY,neutral     0.5000    0.1000    0.1667        10
#            FOOD&DRINKS#QUALITY,positive     0.8214    0.7077    0.7603        65
#          FOOD&DRINKS#STYLE&OPTIONS,None     0.9899    0.9974    0.9936      1956
#      FOOD&DRINKS#STYLE&OPTIONS,negative     0.8000    0.6222    0.7000        45
#       FOOD&DRINKS#STYLE&OPTIONS,neutral     1.0000    0.0000    0.0000         2
#      FOOD&DRINKS#STYLE&OPTIONS,positive     0.7917    0.7037    0.7451        27
#                  HOTEL#CLEANLINESS,None     0.9811    0.9985    0.9897      1978
#              HOTEL#CLEANLINESS,negative     1.0000    0.0000    0.0000         4
#               HOTEL#CLEANLINESS,neutral     1.0000    0.0000    0.0000         2
#              HOTEL#CLEANLINESS,positive     0.8235    0.3043    0.4444        46
#                      HOTEL#COMFORT,None     0.9437    0.9814    0.9622      1775
#                  HOTEL#COMFORT,negative     0.6250    0.1923    0.2941        26
#                   HOTEL#COMFORT,neutral     0.7143    0.4167    0.5263        12
#                  HOTEL#COMFORT,positive     0.7988    0.6221    0.6995       217
#              HOTEL#DESIGN&FEATURES,None     0.9720    0.9954    0.9835      1951
#          HOTEL#DESIGN&FEATURES,negative     1.0000    0.0000    0.0000        12
#           HOTEL#DESIGN&FEATURES,neutral     1.0000    0.0000    0.0000         2
#          HOTEL#DESIGN&FEATURES,positive     0.6875    0.3385    0.4536        65
#                      HOTEL#GENERAL,None     0.9134    0.9652    0.9386      1694
#                  HOTEL#GENERAL,negative     0.7500    0.1765    0.2857        17
#                   HOTEL#GENERAL,neutral     0.3182    0.1167    0.1707        60
#                  HOTEL#GENERAL,positive     0.6028    0.4981    0.5455       259
#                HOTEL#MISCELLANEOUS,None     0.9896    1.0000    0.9948      2006
#            HOTEL#MISCELLANEOUS,negative     0.5000    0.0833    0.1429        12
#             HOTEL#MISCELLANEOUS,neutral     1.0000    0.0000    0.0000         2
#            HOTEL#MISCELLANEOUS,positive     1.0000    0.1000    0.1818        10
#                       HOTEL#PRICES,None     0.9882    0.9898    0.9890      1856
#                   HOTEL#PRICES,negative     1.0000    0.2857    0.4444        14
#                    HOTEL#PRICES,neutral     1.0000    0.0000    0.0000        12
#                   HOTEL#PRICES,positive     0.7964    0.8986    0.8444       148
#                      HOTEL#QUALITY,None     0.9828    0.9959    0.9893      1951
#                  HOTEL#QUALITY,negative     0.6667    0.3077    0.4211        13
#                   HOTEL#QUALITY,neutral     0.6667    0.3636    0.4706        11
#                  HOTEL#QUALITY,positive     0.7073    0.5273    0.6042        55
#                   LOCATION#GENERAL,None     0.9870    0.9938    0.9904      1764
#               LOCATION#GENERAL,negative     0.8261    0.6129    0.7037        31
#                LOCATION#GENERAL,neutral     1.0000    0.0000    0.0000         4
#               LOCATION#GENERAL,positive     0.9177    0.9177    0.9177       231
#                  ROOMS#CLEANLINESS,None     0.9771    0.9804    0.9787      1737
#              ROOMS#CLEANLINESS,negative     0.6875    0.2750    0.3929        40
#               ROOMS#CLEANLINESS,neutral     1.0000    0.0000    0.0000         2
#              ROOMS#CLEANLINESS,positive     0.8561    0.9243    0.8889       251
#                      ROOMS#COMFORT,None     0.9666    0.9932    0.9797      1923
#                  ROOMS#COMFORT,negative     0.7273    0.2286    0.3478        35
#                  ROOMS#COMFORT,positive     0.6744    0.4028    0.5043        72
#              ROOMS#DESIGN&FEATURES,None     0.9645    0.9900    0.9771      1895
#          ROOMS#DESIGN&FEATURES,negative     0.5652    0.3023    0.3939        43
#           ROOMS#DESIGN&FEATURES,neutral     1.0000    0.0000    0.0000         6
#          ROOMS#DESIGN&FEATURES,positive     0.6774    0.4884    0.5676        86
#                      ROOMS#GENERAL,None     0.9707    0.9969    0.9837      1962
#                  ROOMS#GENERAL,negative     1.0000    0.1667    0.2857         6
#                   ROOMS#GENERAL,neutral     1.0000    0.0000    0.0000        11
#                  ROOMS#GENERAL,positive     0.5000    0.1373    0.2154        51
#                ROOMS#MISCELLANEOUS,None     0.9946    1.0000    0.9973      2019
#            ROOMS#MISCELLANEOUS,negative     1.0000    0.0000    0.0000        11
#                       ROOMS#PRICES,None     0.9931    1.0000    0.9965      2013
#                   ROOMS#PRICES,negative     1.0000    0.0000    0.0000         3
#                    ROOMS#PRICES,neutral     1.0000    0.0000    0.0000         2
#                   ROOMS#PRICES,positive     0.6667    0.1667    0.2667        12
#                      ROOMS#QUALITY,None     0.9860    0.9985    0.9922      1971
#                  ROOMS#QUALITY,negative     1.0000    0.0667    0.1250        15
#                   ROOMS#QUALITY,neutral     1.0000    0.0000    0.0000         2
#                  ROOMS#QUALITY,positive     0.7879    0.6190    0.6933        42
#         ROOM_AMENITIES#CLEANLINESS,None     0.9941    1.0000    0.9970      2016
#     ROOM_AMENITIES#CLEANLINESS,negative     1.0000    0.0000    0.0000         9
#     ROOM_AMENITIES#CLEANLINESS,positive     1.0000    0.4000    0.5714         5
#             ROOM_AMENITIES#COMFORT,None     0.9946    0.9995    0.9970      2018
#         ROOM_AMENITIES#COMFORT,negative     0.0000    0.0000    0.0000         7
#         ROOM_AMENITIES#COMFORT,positive     1.0000    0.0000    0.0000         5
#     ROOM_AMENITIES#DESIGN&FEATURES,None     0.9871    0.9985    0.9928      2000
# ROOM_AMENITIES#DESIGN&FEATURES,negative     1.0000    0.0000    0.0000         9
#  ROOM_AMENITIES#DESIGN&FEATURES,neutral     1.0000    0.0000    0.0000         1
# ROOM_AMENITIES#DESIGN&FEATURES,positive     0.5714    0.2000    0.2963        20
#             ROOM_AMENITIES#GENERAL,None     0.9836    0.9804    0.9820      1835
#         ROOM_AMENITIES#GENERAL,negative     1.0000    0.0000    0.0000         5
#          ROOM_AMENITIES#GENERAL,neutral     1.0000    0.0000    0.0000         2
#         ROOM_AMENITIES#GENERAL,positive     0.8109    0.8670    0.8380       188
#       ROOM_AMENITIES#MISCELLANEOUS,None     0.9866    0.9975    0.9920      1992
#   ROOM_AMENITIES#MISCELLANEOUS,negative     0.6250    0.3030    0.4082        33
#    ROOM_AMENITIES#MISCELLANEOUS,neutral     1.0000    0.0000    0.0000         2
#   ROOM_AMENITIES#MISCELLANEOUS,positive     1.0000    0.0000    0.0000         3
#              ROOM_AMENITIES#PRICES,None     0.9995    1.0000    0.9998      2029
#          ROOM_AMENITIES#PRICES,negative     1.0000    0.0000    0.0000         1
#             ROOM_AMENITIES#QUALITY,None     0.9786    0.9970    0.9877      1969
#         ROOM_AMENITIES#QUALITY,negative     0.7000    0.3256    0.4444        43
#          ROOM_AMENITIES#QUALITY,neutral     1.0000    0.0000    0.0000         1
#         ROOM_AMENITIES#QUALITY,positive     0.5000    0.1176    0.1905        17
#                    SERVICE#GENERAL,None     0.9456    0.9368    0.9412      1392
#                SERVICE#GENERAL,negative     0.5942    0.4940    0.5395        83
#                 SERVICE#GENERAL,neutral     0.6500    0.4194    0.5098        31
#                SERVICE#GENERAL,positive     0.8345    0.8950    0.8637       524
#
#                                accuracy                         0.9755     69020
#                               macro avg     0.8847    0.4302    0.4629     69020
#                            weighted avg     0.9729    0.9755    0.9716     69020

# %%
y_pred = ypred_svm_moc
y_test_rs = y_test


# Evaluate Multi ouput classifier
ad = aspect_detection_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
ast = sentiment_classification_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
cp = combination_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
# Out:
# ## Aspect Detection Evaluate ##
# F1-score micro:  0.9778325123152709
# F1-score macro:  0.422199376275569
#                                 precision    recall  f1-score   support
#
#                                    0.9818    0.9951    0.9884     65760
#         FACILITIES#CLEANLINESS     1.0000    0.3750    0.5455        16
#             FACILITIES#COMFORT     1.0000    0.0000    0.0000         6
#     FACILITIES#DESIGN&FEATURES     1.0000    0.2941    0.4545        17
#             FACILITIES#GENERAL     0.5833    0.1556    0.2456        45
#       FACILITIES#MISCELLANEOUS     1.0000    0.0000    0.0000        11
#              FACILITIES#PRICES     1.0000    0.0000    0.0000         6
#             FACILITIES#QUALITY     1.0000    0.1818    0.3077        22
#      FOOD&DRINKS#MISCELLANEOUS     1.0000    0.0000    0.0000         9
#             FOOD&DRINKS#PRICES     1.0000    0.0000    0.0000         8
#            FOOD&DRINKS#QUALITY     0.8889    0.6275    0.7356       102
#      FOOD&DRINKS#STYLE&OPTIONS     0.9153    0.7297    0.8120        74
#              HOTEL#CLEANLINESS     0.8235    0.2692    0.4058        52
#                  HOTEL#COMFORT     0.8187    0.5843    0.6819       255
#          HOTEL#DESIGN&FEATURES     0.6944    0.3165    0.4348        79
#                  HOTEL#GENERAL     0.7500    0.4911    0.5935       336
#            HOTEL#MISCELLANEOUS     1.0000    0.1250    0.2222        24
#                   HOTEL#PRICES     0.8988    0.8678    0.8830       174
#                  HOTEL#QUALITY     0.8235    0.5316    0.6462        79
#               LOCATION#GENERAL     0.9605    0.9135    0.9364       266
#              ROOMS#CLEANLINESS     0.8804    0.8294    0.8541       293
#                  ROOMS#COMFORT     0.7857    0.3084    0.4430       107
#          ROOMS#DESIGN&FEATURES     0.7671    0.4148    0.5385       135
#                  ROOMS#GENERAL     0.6000    0.0882    0.1538        68
#            ROOMS#MISCELLANEOUS     1.0000    0.0000    0.0000        11
#                   ROOMS#PRICES     1.0000    0.2353    0.3810        17
#                  ROOMS#QUALITY     0.9118    0.5254    0.6667        59
#     ROOM_AMENITIES#CLEANLINESS     1.0000    0.1429    0.2500        14
#         ROOM_AMENITIES#COMFORT     0.0000    0.0000    0.0000        12
# ROOM_AMENITIES#DESIGN&FEATURES     0.5714    0.1333    0.2162        30
#         ROOM_AMENITIES#GENERAL     0.8750    0.8256    0.8496       195
#   ROOM_AMENITIES#MISCELLANEOUS     0.7500    0.1579    0.2609        38
#          ROOM_AMENITIES#PRICES     1.0000    0.0000    0.0000         1
#         ROOM_AMENITIES#QUALITY     0.7273    0.2623    0.3855        61
#                SERVICE#GENERAL     0.8995    0.8699    0.8845       638
#
#                       accuracy                         0.9778     69020
#                      macro avg     0.8545    0.3500    0.4222     69020
#                   weighted avg     0.9754    0.9778    0.9745     69020
#
# ## Sentiment Classification Evaluate ##
# F1-score micro:  0.9753549695740366
# F1-score macro:  0.5894574513178257
#               precision    recall  f1-score   support
#
#         None     0.9818    0.9951    0.9884     65760
#     negative     0.7354    0.2658    0.3905       617
#      neutral     0.5185    0.1547    0.2383       181
#     positive     0.8063    0.6848    0.7406      2462
#
#     accuracy                         0.9754     69020
#    macro avg     0.7605    0.5251    0.5895     69020
# weighted avg     0.9722    0.9754    0.9723     69020
#
# ## Combination Evaluate (Aspect + Polarity dection) ##
# F1-score micro:  0.9753549695740366
# F1-score macro:  0.45650573768569064
#                                          precision    recall  f1-score   support
#
#             FACILITIES#CLEANLINESS,None     0.9951    1.0000    0.9975      2014
#         FACILITIES#CLEANLINESS,negative     0.8000    0.3636    0.5000        11
#         FACILITIES#CLEANLINESS,positive     1.0000    0.2000    0.3333         5
#                 FACILITIES#COMFORT,None     0.9970    1.0000    0.9985      2024
#             FACILITIES#COMFORT,negative     1.0000    0.0000    0.0000         4
#             FACILITIES#COMFORT,positive     1.0000    0.0000    0.0000         2
#         FACILITIES#DESIGN&FEATURES,None     0.9941    1.0000    0.9970      2013
#     FACILITIES#DESIGN&FEATURES,negative     1.0000    0.2500    0.4000        12
#     FACILITIES#DESIGN&FEATURES,positive     0.5000    0.2000    0.2857         5
#                 FACILITIES#GENERAL,None     0.9812    0.9975    0.9893      1985
#             FACILITIES#GENERAL,negative     1.0000    0.0000    0.0000         6
#              FACILITIES#GENERAL,neutral     1.0000    0.0000    0.0000         3
#             FACILITIES#GENERAL,positive     0.5833    0.1944    0.2917        36
#           FACILITIES#MISCELLANEOUS,None     0.9946    1.0000    0.9973      2019
#       FACILITIES#MISCELLANEOUS,negative     1.0000    0.0000    0.0000         9
#       FACILITIES#MISCELLANEOUS,positive     1.0000    0.0000    0.0000         2
#                  FACILITIES#PRICES,None     0.9970    1.0000    0.9985      2024
#              FACILITIES#PRICES,negative     1.0000    0.0000    0.0000         4
#              FACILITIES#PRICES,positive     1.0000    0.0000    0.0000         2
#                 FACILITIES#QUALITY,None     0.9911    1.0000    0.9955      2008
#             FACILITIES#QUALITY,negative     0.7500    0.2143    0.3333        14
#              FACILITIES#QUALITY,neutral     1.0000    0.0000    0.0000         1
#             FACILITIES#QUALITY,positive     1.0000    0.0000    0.0000         7
#          FOOD&DRINKS#MISCELLANEOUS,None     0.9956    1.0000    0.9978      2021
#      FOOD&DRINKS#MISCELLANEOUS,negative     1.0000    0.0000    0.0000         8
#      FOOD&DRINKS#MISCELLANEOUS,positive     1.0000    0.0000    0.0000         1
#                 FOOD&DRINKS#PRICES,None     0.9961    1.0000    0.9980      2022
#             FOOD&DRINKS#PRICES,negative     1.0000    0.0000    0.0000         5
#             FOOD&DRINKS#PRICES,positive     1.0000    0.0000    0.0000         3
#                FOOD&DRINKS#QUALITY,None     0.9806    0.9959    0.9882      1928
#            FOOD&DRINKS#QUALITY,negative     0.9167    0.4074    0.5641        27
#             FOOD&DRINKS#QUALITY,neutral     0.3333    0.1000    0.1538        10
#            FOOD&DRINKS#QUALITY,positive     0.8246    0.7231    0.7705        65
#          FOOD&DRINKS#STYLE&OPTIONS,None     0.9899    0.9974    0.9936      1956
#      FOOD&DRINKS#STYLE&OPTIONS,negative     0.7778    0.6222    0.6914        45
#       FOOD&DRINKS#STYLE&OPTIONS,neutral     1.0000    0.0000    0.0000         2
#      FOOD&DRINKS#STYLE&OPTIONS,positive     0.8261    0.7037    0.7600        27
#                  HOTEL#CLEANLINESS,None     0.9811    0.9985    0.9897      1978
#              HOTEL#CLEANLINESS,negative     1.0000    0.0000    0.0000         4
#               HOTEL#CLEANLINESS,neutral     1.0000    0.0000    0.0000         2
#              HOTEL#CLEANLINESS,positive     0.8235    0.3043    0.4444        46
#                      HOTEL#COMFORT,None     0.9426    0.9814    0.9616      1775
#                  HOTEL#COMFORT,negative     0.7143    0.1923    0.3030        26
#                   HOTEL#COMFORT,neutral     0.7143    0.4167    0.5263        12
#                  HOTEL#COMFORT,positive     0.7976    0.6175    0.6961       217
#              HOTEL#DESIGN&FEATURES,None     0.9729    0.9944    0.9835      1951
#          HOTEL#DESIGN&FEATURES,negative     1.0000    0.0000    0.0000        12
#           HOTEL#DESIGN&FEATURES,neutral     1.0000    0.0000    0.0000         2
#          HOTEL#DESIGN&FEATURES,positive     0.6667    0.3692    0.4752        65
#                      HOTEL#GENERAL,None     0.9055    0.9675    0.9355      1694
#                  HOTEL#GENERAL,negative     1.0000    0.2353    0.3810        17
#                   HOTEL#GENERAL,neutral     0.3684    0.1167    0.1772        60
#                  HOTEL#GENERAL,positive     0.6041    0.4595    0.5219       259
#                HOTEL#MISCELLANEOUS,None     0.9896    1.0000    0.9948      2006
#            HOTEL#MISCELLANEOUS,negative     0.5000    0.0833    0.1429        12
#             HOTEL#MISCELLANEOUS,neutral     1.0000    0.0000    0.0000         2
#            HOTEL#MISCELLANEOUS,positive     1.0000    0.1000    0.1818        10
#                       HOTEL#PRICES,None     0.9876    0.9908    0.9892      1856
#                   HOTEL#PRICES,negative     0.8000    0.2857    0.4211        14
#                    HOTEL#PRICES,neutral     1.0000    0.0000    0.0000        12
#                   HOTEL#PRICES,positive     0.8037    0.8851    0.8424       148
#                      HOTEL#QUALITY,None     0.9813    0.9954    0.9883      1951
#                  HOTEL#QUALITY,negative     0.7143    0.3846    0.5000        13
#                   HOTEL#QUALITY,neutral     0.5714    0.3636    0.4444        11
#                  HOTEL#QUALITY,positive     0.6757    0.4545    0.5435        55
#                   LOCATION#GENERAL,None     0.9871    0.9943    0.9907      1764
#               LOCATION#GENERAL,negative     0.8696    0.6452    0.7407        31
#                LOCATION#GENERAL,neutral     1.0000    0.0000    0.0000         4
#               LOCATION#GENERAL,positive     0.9174    0.9134    0.9154       231
#                  ROOMS#CLEANLINESS,None     0.9715    0.9810    0.9762      1737
#              ROOMS#CLEANLINESS,negative     0.6875    0.2750    0.3929        40
#               ROOMS#CLEANLINESS,neutral     1.0000    0.0000    0.0000         2
#              ROOMS#CLEANLINESS,positive     0.8577    0.8884    0.8728       251
#                      ROOMS#COMFORT,None     0.9628    0.9953    0.9788      1923
#                  ROOMS#COMFORT,negative     0.7778    0.2000    0.3182        35
#                  ROOMS#COMFORT,positive     0.6667    0.3056    0.4190        72
#              ROOMS#DESIGN&FEATURES,None     0.9596    0.9910    0.9751      1895
#          ROOMS#DESIGN&FEATURES,negative     0.5000    0.1860    0.2712        43
#           ROOMS#DESIGN&FEATURES,neutral     1.0000    0.0000    0.0000         6
#          ROOMS#DESIGN&FEATURES,positive     0.6491    0.4302    0.5175        86
#                      ROOMS#GENERAL,None     0.9693    0.9980    0.9834      1962
#                  ROOMS#GENERAL,negative     1.0000    0.1667    0.2857         6
#                   ROOMS#GENERAL,neutral     1.0000    0.0000    0.0000        11
#                  ROOMS#GENERAL,positive     0.4444    0.0784    0.1333        51
#                ROOMS#MISCELLANEOUS,None     0.9946    1.0000    0.9973      2019
#            ROOMS#MISCELLANEOUS,negative     1.0000    0.0000    0.0000        11
#                       ROOMS#PRICES,None     0.9936    1.0000    0.9968      2013
#                   ROOMS#PRICES,negative     1.0000    0.0000    0.0000         3
#                    ROOMS#PRICES,neutral     1.0000    0.0000    0.0000         2
#                   ROOMS#PRICES,positive     0.7500    0.2500    0.3750        12
#                      ROOMS#QUALITY,None     0.9860    0.9985    0.9922      1971
#                  ROOMS#QUALITY,negative     1.0000    0.0667    0.1250        15
#                   ROOMS#QUALITY,neutral     1.0000    0.0000    0.0000         2
#                  ROOMS#QUALITY,positive     0.7879    0.6190    0.6933        42
#         ROOM_AMENITIES#CLEANLINESS,None     0.9941    1.0000    0.9970      2016
#     ROOM_AMENITIES#CLEANLINESS,negative     1.0000    0.0000    0.0000         9
#     ROOM_AMENITIES#CLEANLINESS,positive     1.0000    0.4000    0.5714         5
#             ROOM_AMENITIES#COMFORT,None     0.9941    0.9995    0.9968      2018
#         ROOM_AMENITIES#COMFORT,negative     0.0000    0.0000    0.0000         7
#         ROOM_AMENITIES#COMFORT,positive     1.0000    0.0000    0.0000         5
#     ROOM_AMENITIES#DESIGN&FEATURES,None     0.9871    0.9985    0.9928      2000
# ROOM_AMENITIES#DESIGN&FEATURES,negative     1.0000    0.0000    0.0000         9
#  ROOM_AMENITIES#DESIGN&FEATURES,neutral     1.0000    0.0000    0.0000         1
# ROOM_AMENITIES#DESIGN&FEATURES,positive     0.5714    0.2000    0.2963        20
#             ROOM_AMENITIES#GENERAL,None     0.9816    0.9875    0.9845      1835
#         ROOM_AMENITIES#GENERAL,negative     1.0000    0.0000    0.0000         5
#          ROOM_AMENITIES#GENERAL,neutral     1.0000    0.0000    0.0000         2
#         ROOM_AMENITIES#GENERAL,positive     0.8641    0.8457    0.8548       188
#       ROOM_AMENITIES#MISCELLANEOUS,None     0.9842    0.9990    0.9915      1992
#   ROOM_AMENITIES#MISCELLANEOUS,negative     0.7500    0.1818    0.2927        33
#    ROOM_AMENITIES#MISCELLANEOUS,neutral     1.0000    0.0000    0.0000         2
#   ROOM_AMENITIES#MISCELLANEOUS,positive     1.0000    0.0000    0.0000         3
#              ROOM_AMENITIES#PRICES,None     0.9995    1.0000    0.9998      2029
#          ROOM_AMENITIES#PRICES,negative     1.0000    0.0000    0.0000         1
#             ROOM_AMENITIES#QUALITY,None     0.9776    0.9970    0.9872      1969
#         ROOM_AMENITIES#QUALITY,negative     0.6471    0.2558    0.3667        43
#          ROOM_AMENITIES#QUALITY,neutral     1.0000    0.0000    0.0000         1
#         ROOM_AMENITIES#QUALITY,positive     0.4000    0.1176    0.1818        17
#                    SERVICE#GENERAL,None     0.9413    0.9555    0.9483      1392
#                SERVICE#GENERAL,negative     0.6739    0.3735    0.4806        83
#                 SERVICE#GENERAL,neutral     0.6111    0.3548    0.4490        31
#                SERVICE#GENERAL,positive     0.8499    0.8969    0.8728       524
#
#                                accuracy                         0.9754     69020
#                               macro avg     0.8828    0.4239    0.4565     69020
#                            weighted avg     0.9723    0.9754    0.9710     69020
