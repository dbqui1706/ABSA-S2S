# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U --q emoji underthesea
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 16.5 MB/s eta 0:00:00

# %%
# %cd '/content/drive/MyDrive/NLU_NCKH/notebook/res_data_preprocesed/'
# Out:
# /content/drive/MyDrive/NLU_NCKH/notebook/res_data_preprocesed

# %% [markdown]
# # Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import torch
from sklearn.metrics import *

# %% [markdown]
# # Load data

# %%
df_train = pd.read_csv("train_res_preprocesed.csv")
df_dev = pd.read_csv("dev_res_preprocesed.csv")
df_test = pd.read_csv("test_res_preprocesed.csv")

print("Train: ", df_train.shape)
print("Dev: ",  df_dev.shape)
print("Test: ", df_test.shape )
# Out:
# Train:  (7028, 13)
# Dev:  (771, 13)
# Test:  (1938, 13)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

aspects = df_train.columns[1:]
def make_outputs(df):
    outputs = []
    for row in range(len(df)):
        row_one_hot = []
        for col in range(1, len(df.columns)):
            sentiment = df.iloc[row, col]
            if   sentiment == 0: one_hot = [1, 0, 0, 0] # None
            elif sentiment == 1: one_hot = [0, 1, 0, 0] # Pos
            elif sentiment == 2: one_hot = [0, 0, 1, 0] # Neg
            elif sentiment == 3: one_hot = [0, 0, 0, 1] # Neu
            row_one_hot.append(one_hot)
        outputs.append(np.array(row_one_hot).reshape(-1))
    return np.array(outputs, dtype='uint8')

x_train = df_train['review']
y_train = make_outputs(df_train)

x_test = df_test['review']
y_test = make_outputs(df_test)

vectorizer = TfidfVectorizer(ngram_range=(1, 3),
                             min_df=2, max_df=0.9)

# x data using basic clean up class and basic features extrator
x_train = vectorizer.fit_transform(x_train)
x_test   = vectorizer.transform(x_test)

x_train.shape, y_train.shape
# Out:
# ((7028, 20068), (7028, 48))

# %%
import os
import math
from tqdm import tqdm, trange
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, f1_score

label_map= {'None': 0,
            'negative':1,
            'neutral':2,
            'positive':3}

replacements={0: 'None',
              1: 'negative',
              2: 'neutral',
              3: 'positive'}
target_names = list(map(str, replacements.values()))

def aspect_detection_eval(y_test, y_pred):
  """
  y_test: grouth_true test, DataFrame
  y_pred: grouth_true predict, DataFrame
  """
  categories= y_pred.columns
  y_test= y_test.fillna('not_exist').replace(label_map).values.tolist()
  y_pred= y_pred.fillna('not_exist').replace(label_map).values.tolist()

  aspect_test = []
  aspect_pred = []

  for row_test, row_pred in zip(y_test, y_pred):
      for index, (col_test, col_pred) in enumerate(zip(row_test, row_pred)):
          aspect_test.append(bool(col_test) * categories[index])
          aspect_pred.append(bool(col_pred) * categories[index])

  print("## Aspect Detection Evaluate ##")
  print("F1-score micro: ", f1_score(aspect_test, aspect_pred, average='micro'))
  print("F1-score macro: ", f1_score(aspect_test, aspect_pred, average='macro'))
  print(classification_report(aspect_test, aspect_pred, digits=4, zero_division=1))
  return classification_report(aspect_test, aspect_pred, digits=4, zero_division=1, output_dict=True)


def sentiment_classification_eval(y_test, y_pred):
  """
  y_test: grouth_true test, DataFrame
  y_pred: grouth_true predict, DataFrame
  """
  categories= y_pred.columns
  y_test= y_test.fillna('not_exist').replace(label_map).values.tolist()
  y_pred= y_pred.fillna('not_exist').replace(label_map).values.tolist()

  y_test_flat = np.array(y_test).flatten()
  y_pred_flat = np.array(y_pred).flatten()
  target_names = list(map(str, replacements.values()))

  print("## Sentiment Classification Evaluate ##")
  print("F1-score micro: ", f1_score(y_test_flat, y_pred_flat, average='micro'))
  print("F1-score macro: ", f1_score(y_test_flat, y_pred_flat, average='macro'))
  print(classification_report(y_test_flat, y_pred_flat, target_names=target_names, digits=4))

  return classification_report(y_test_flat, y_pred_flat, digits=4, output_dict=True)

def combination_eval(y_test, y_pred):
  """
  y_test: grouth_true test, DataFrame
  y_pred: grouth_true predict, DataFrame
  """
  categories= y_pred.columns
  y_test= y_test.fillna('not_exist').replace(label_map).values.tolist()
  y_pred= y_pred.fillna('not_exist').replace(label_map).values.tolist()

  aspect_polarity_test = []
  aspect_polarity_pred = []

  for row_test, row_pred in zip(y_test, y_pred):
      for index, (col_test, col_pred) in enumerate(zip(row_test, row_pred)):
          aspect_polarity_test.append(f'{categories[index]},{replacements[col_test]}')
          aspect_polarity_pred.append(f'{categories[index]},{replacements[col_pred]}')

  print("## Combination Evaluate (Aspect + Polarity dection) ##")
  print("F1-score micro: ", f1_score(aspect_polarity_test, aspect_polarity_pred, average='micro'))
  print("F1-score macro: ", f1_score(aspect_polarity_test, aspect_polarity_pred, average='macro'))
  print(classification_report(aspect_polarity_test, aspect_polarity_pred, digits=4, zero_division=1))
  return classification_report(aspect_polarity_test, aspect_polarity_pred, digits=4, zero_division=1, output_dict=True)

# %%
from sklearn.svm import LinearSVC
from sklearn.multioutput import MultiOutputClassifier as MOC
from sklearn.multioutput import ClassifierChain as MOC_CC

clf_moc = MOC(LinearSVC(random_state=5))
clf_cc = MOC_CC(LinearSVC(random_state=5))

clf_moc.fit(x_train, y_train)
clf_cc.fit(x_train, y_train)

ypred_svm_moc = clf_moc.predict(x_test)
ypred_svm_cc = clf_cc.predict(x_test)

# %% [markdown]
# # Evaluate

# %%
ypred_svm_moc_rs = ypred_svm_cc.reshape(-1, 12, 4)
y_test_rs = y_test.reshape(-1, 12, 4)

y_test_flat = np.argmax(y_test_rs, axis=2)
y_pred = np.argmax(ypred_svm_moc_rs, axis=2)

# Evaluate Classifier Chain
ad = aspect_detection_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
ast = sentiment_classification_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
cp = combination_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
# Out:
# ## Aspect Detection Evaluate ##
# F1-score micro:  0.9458204334365325
# F1-score macro:  0.6913527755463968
#                           precision    recall  f1-score   support
#
#                              0.9621    0.9774    0.9697     20627
#         AMBIENCE#GENERAL     0.9378    0.7974    0.8619       227
#            DRINKS#PRICES     0.7273    0.1702    0.2759        47
#           DRINKS#QUALITY     0.7222    0.7044    0.7132       203
#     DRINKS#STYLE&OPTIONS     0.7374    0.5659    0.6404       129
#              FOOD#PRICES     0.6098    0.2232    0.3268       112
#             FOOD#QUALITY     0.7789    0.8520    0.8138       554
#       FOOD#STYLE&OPTIONS     0.7353    0.7437    0.7395       437
#         LOCATION#GENERAL     0.9859    0.6731    0.8000       104
#       RESTAURANT#GENERAL     0.7674    0.5259    0.6241       251
# RESTAURANT#MISCELLANEOUS     0.8667    0.5379    0.6638       145
#        RESTAURANT#PRICES     0.6903    0.6667    0.6783       117
#          SERVICE#GENERAL     0.9434    0.8251    0.8803       303
#
#                 accuracy                         0.9458     23256
#                macro avg     0.8050    0.6356    0.6914     23256
#             weighted avg     0.9435    0.9458    0.9430     23256
#
# ## Sentiment Classification Evaluate ##
# F1-score micro:  0.9287925696594427
# F1-score macro:  0.6433139111400297
#               precision    recall  f1-score   support
#
#         None     0.9621    0.9774    0.9697     20627
#     negative     0.7345    0.3816    0.5023       435
#      neutral     0.5153    0.3907    0.4444       691
#     positive     0.6467    0.6673    0.6568      1503
#
#     accuracy                         0.9288     23256
#    macro avg     0.7146    0.6043    0.6433     23256
# weighted avg     0.9242    0.9288    0.9251     23256
#
# ## Combination Evaluate (Aspect + Polarity dection) ##
# F1-score micro:  0.9287925696594427
# F1-score macro:  0.5585981293324119
#                                    precision    recall  f1-score   support
#
#             AMBIENCE#GENERAL,None     0.9736    0.9930    0.9832      1711
#         AMBIENCE#GENERAL,negative     0.8636    0.5135    0.6441        37
#          AMBIENCE#GENERAL,neutral     0.3333    0.2000    0.2500        30
#         AMBIENCE#GENERAL,positive     0.8301    0.7937    0.8115       160
#                DRINKS#PRICES,None     0.9798    0.9984    0.9890      1891
#            DRINKS#PRICES,negative     0.0000    0.0000    0.0000         5
#             DRINKS#PRICES,neutral     0.5556    0.1562    0.2439        32
#            DRINKS#PRICES,positive     1.0000    0.1000    0.1818        10
#               DRINKS#QUALITY,None     0.9655    0.9683    0.9669      1735
#           DRINKS#QUALITY,negative     0.3333    0.0385    0.0690        26
#            DRINKS#QUALITY,neutral     0.5625    0.1875    0.2812        48
#           DRINKS#QUALITY,positive     0.4804    0.6667    0.5584       129
#         DRINKS#STYLE&OPTIONS,None     0.9695    0.9856    0.9775      1809
#     DRINKS#STYLE&OPTIONS,negative     1.0000    0.1000    0.1818        10
#      DRINKS#STYLE&OPTIONS,neutral     0.5000    0.5323    0.5156        62
#     DRINKS#STYLE&OPTIONS,positive     0.5625    0.3158    0.4045        57
#                  FOOD#PRICES,None     0.9541    0.9912    0.9723      1826
#              FOOD#PRICES,negative     0.0000    0.0000    0.0000        10
#               FOOD#PRICES,neutral     0.5625    0.2535    0.3495        71
#              FOOD#PRICES,positive     0.5000    0.1290    0.2051        31
#                 FOOD#QUALITY,None     0.9384    0.9032    0.9205      1384
#             FOOD#QUALITY,negative     0.7333    0.2821    0.4074        78
#              FOOD#QUALITY,neutral     0.5806    0.4800    0.5255        75
#             FOOD#QUALITY,positive     0.6634    0.8504    0.7454       401
#           FOOD#STYLE&OPTIONS,None     0.9251    0.9221    0.9236      1501
#       FOOD#STYLE&OPTIONS,negative     0.6667    0.2759    0.3902        58
#        FOOD#STYLE&OPTIONS,neutral     0.4860    0.5029    0.4943       173
#       FOOD#STYLE&OPTIONS,positive     0.5021    0.5825    0.5393       206
#             LOCATION#GENERAL,None     0.9818    0.9995    0.9905      1834
#         LOCATION#GENERAL,negative     1.0000    0.2000    0.3333        10
#          LOCATION#GENERAL,neutral     0.6579    0.5682    0.6098        44
#         LOCATION#GENERAL,positive     0.9677    0.6000    0.7407        50
#           RESTAURANT#GENERAL,None     0.9326    0.9763    0.9540      1687
#       RESTAURANT#GENERAL,negative     0.6000    0.1622    0.2553        37
#        RESTAURANT#GENERAL,neutral     0.4634    0.3220    0.3800        59
#       RESTAURANT#GENERAL,positive     0.5868    0.4581    0.5145       155
#     RESTAURANT#MISCELLANEOUS,None     0.9637    0.9933    0.9783      1793
# RESTAURANT#MISCELLANEOUS,negative     0.6500    0.3824    0.4815        34
#  RESTAURANT#MISCELLANEOUS,neutral     0.2000    0.0526    0.0833        19
# RESTAURANT#MISCELLANEOUS,positive     0.6615    0.4674    0.5478        92
#            RESTAURANT#PRICES,None     0.9786    0.9808    0.9797      1821
#        RESTAURANT#PRICES,negative     0.7500    0.5769    0.6522        26
#         RESTAURANT#PRICES,neutral     0.5094    0.4909    0.5000        55
#        RESTAURANT#PRICES,positive     0.4250    0.4722    0.4474        36
#              SERVICE#GENERAL,None     0.9683    0.9908    0.9794      1635
#          SERVICE#GENERAL,negative     0.7717    0.6827    0.7245       104
#           SERVICE#GENERAL,neutral     0.8000    0.1739    0.2857        23
#          SERVICE#GENERAL,positive     0.8631    0.8239    0.8430       176
#
#                          accuracy                         0.9288     23256
#                         macro avg     0.6907    0.5228    0.5586     23256
#                      weighted avg     0.9242    0.9288    0.9233     23256

# %%
ypred_svm_moc_rs = ypred_svm_moc.reshape(-1, 12, 4)
y_test_rs = y_test.reshape(-1, 12, 4)

y_test_flat = np.argmax(y_test_rs, axis=2)
y_pred = np.argmax(ypred_svm_moc_rs, axis=2)

# Evaluate Multi ouput classifier
ad = aspect_detection_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
ast = sentiment_classification_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
cp = combination_eval(df_test[aspects], pd.DataFrame(y_pred, columns=aspects))
# Out:
# ## Aspect Detection Evaluate ##
# F1-score micro:  0.9284055727554179
# F1-score macro:  0.5189421725486433
#                           precision    recall  f1-score   support
#
#                              0.9309    0.9930    0.9609     20627
#         AMBIENCE#GENERAL     0.9606    0.5374    0.6893       227
#            DRINKS#PRICES     1.0000    0.0426    0.0816        47
#           DRINKS#QUALITY     0.8056    0.4286    0.5595       203
#     DRINKS#STYLE&OPTIONS     0.8529    0.2248    0.3558       129
#              FOOD#PRICES     0.5769    0.1339    0.2174       112
#             FOOD#QUALITY     0.8427    0.5704    0.6803       554
#       FOOD#STYLE&OPTIONS     0.8549    0.3776    0.5238       437
#         LOCATION#GENERAL     1.0000    0.4423    0.6133       104
#       RESTAURANT#GENERAL     0.8696    0.2390    0.3750       251
# RESTAURANT#MISCELLANEOUS     1.0000    0.2621    0.4153       145
#        RESTAURANT#PRICES     0.9130    0.3590    0.5153       117
#          SERVICE#GENERAL     0.9842    0.6172    0.7586       303
#
#                 accuracy                         0.9284     23256
#                macro avg     0.8916    0.4021    0.5189     23256
#             weighted avg     0.9253    0.9284    0.9150     23256
#
# ## Sentiment Classification Evaluate ##
# F1-score micro:  0.9231166150670794
# F1-score macro:  0.5689228299669042
#               precision    recall  f1-score   support
#
#         None     0.9309    0.9930    0.9609     20627
#     negative     0.7803    0.2368    0.3633       435
#      neutral     0.6736    0.2330    0.3462       691
#     positive     0.8177    0.4804    0.6052      1503
#
#     accuracy                         0.9231     23256
#    macro avg     0.8006    0.4858    0.5689     23256
# weighted avg     0.9131    0.9231    0.9085     23256
#
# ## Combination Evaluate (Aspect + Polarity dection) ##
# F1-score micro:  0.9231166150670794
# F1-score macro:  0.4755000593307454
#                                    precision    recall  f1-score   support
#
#             AMBIENCE#GENERAL,None     0.9420    0.9971    0.9688      1711
#         AMBIENCE#GENERAL,negative     0.9000    0.2432    0.3830        37
#          AMBIENCE#GENERAL,neutral     0.3000    0.1000    0.1500        30
#         AMBIENCE#GENERAL,positive     0.9159    0.6125    0.7341       160
#                DRINKS#PRICES,None     0.9768    1.0000    0.9882      1891
#            DRINKS#PRICES,negative     1.0000    0.0000    0.0000         5
#             DRINKS#PRICES,neutral     1.0000    0.0625    0.1176        32
#            DRINKS#PRICES,positive     1.0000    0.0000    0.0000        10
#               DRINKS#QUALITY,None     0.9366    0.9879    0.9616      1735
#           DRINKS#QUALITY,negative     0.0000    0.0000    0.0000        26
#            DRINKS#QUALITY,neutral     0.8000    0.0833    0.1509        48
#           DRINKS#QUALITY,positive     0.6078    0.4806    0.5368       129
#         DRINKS#STYLE&OPTIONS,None     0.9475    0.9972    0.9717      1809
#     DRINKS#STYLE&OPTIONS,negative     1.0000    0.0000    0.0000        10
#      DRINKS#STYLE&OPTIONS,neutral     0.7000    0.3387    0.4565        62
#     DRINKS#STYLE&OPTIONS,positive     1.0000    0.0702    0.1311        57
#                  FOOD#PRICES,None     0.9493    0.9940    0.9711      1826
#              FOOD#PRICES,negative     0.0000    0.0000    0.0000        10
#               FOOD#PRICES,neutral     0.5909    0.1831    0.2796        71
#              FOOD#PRICES,positive     0.3333    0.0323    0.0588        31
#                 FOOD#QUALITY,None     0.8477    0.9574    0.8992      1384
#             FOOD#QUALITY,negative     0.9091    0.2564    0.4000        78
#              FOOD#QUALITY,neutral     0.8500    0.2267    0.3579        75
#             FOOD#QUALITY,positive     0.7988    0.6633    0.7248       401
#           FOOD#STYLE&OPTIONS,None     0.8441    0.9813    0.9076      1501
#       FOOD#STYLE&OPTIONS,negative     0.8235    0.2414    0.3733        58
#        FOOD#STYLE&OPTIONS,neutral     0.6322    0.3179    0.4231       173
#       FOOD#STYLE&OPTIONS,positive     0.7416    0.3204    0.4475       206
#             LOCATION#GENERAL,None     0.9693    1.0000    0.9844      1834
#         LOCATION#GENERAL,negative     1.0000    0.1000    0.1818        10
#          LOCATION#GENERAL,neutral     0.6818    0.3409    0.4545        44
#         LOCATION#GENERAL,positive     0.9565    0.4400    0.6027        50
#           RESTAURANT#GENERAL,None     0.8978    0.9947    0.9438      1687
#       RESTAURANT#GENERAL,negative     0.8000    0.1081    0.1905        37
#        RESTAURANT#GENERAL,neutral     0.7857    0.1864    0.3014        59
#       RESTAURANT#GENERAL,positive     0.7800    0.2516    0.3805       155
#     RESTAURANT#MISCELLANEOUS,None     0.9437    1.0000    0.9710      1793
# RESTAURANT#MISCELLANEOUS,negative     0.6667    0.1765    0.2791        34
#  RESTAURANT#MISCELLANEOUS,neutral     0.0000    0.0000    0.0000        19
# RESTAURANT#MISCELLANEOUS,positive     0.9630    0.2826    0.4370        92
#            RESTAURANT#PRICES,None     0.9604    0.9978    0.9787      1821
#        RESTAURANT#PRICES,negative     0.7273    0.3077    0.4324        26
#         RESTAURANT#PRICES,neutral     0.8261    0.3455    0.4872        55
#        RESTAURANT#PRICES,positive     0.8333    0.2778    0.4167        36
#              SERVICE#GENERAL,None     0.9336    0.9982    0.9648      1635
#          SERVICE#GENERAL,negative     0.7455    0.3942    0.5157       104
#           SERVICE#GENERAL,neutral     0.5000    0.0435    0.0800        23
#          SERVICE#GENERAL,positive     0.9624    0.7273    0.8285       176
#
#                          accuracy                         0.9231     23256
#                         macro avg     0.7767    0.4192    0.4755     23256
#                      weighted avg     0.9142    0.9231    0.9064     23256
